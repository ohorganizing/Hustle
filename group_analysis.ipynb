# %%
import pandas as pd
from datetime import date
today = date.today()
print(f'Last run: {today}')
# Out:
# Last run: 2022-02-28

# %% [markdown]
# ## Analyze Hustle Groups
# - 5k max contacts perHustle TCR campaign

# %% [markdown]
# #### Import packages

# %%
osa_uc = pd.read_csv(r'C:\Users\OOC User\Documents\OOC\Data\Hustle\Groups\OSA\OSA University of Cincinnati_empty.csv')
osa_osu = pd.read_csv(r'C:\Users\OOC User\Documents\OOC\Data\Hustle\Groups\OSA\Ohio State_empty.csv')
osa_cs = pd.read_csv(r'C:\Users\OOC User\Documents\OOC\Data\Hustle\Groups\OSA\OSA Central State_empty.csv')
osa_cles = pd.read_csv(r'C:\Users\OOC User\Documents\OOC\Data\Hustle\Groups\OSA\OSA Cleveland State.csv')
osa_cle = pd.read_csv(r'C:\Users\OOC User\Documents\OOC\Data\Hustle\Groups\OSA\OSA Cleveland.csv')
osa_cwru = pd.read_csv(r'C:\Users\OOC User\Documents\OOC\Data\Hustle\Groups\OSA\OSA CWRU.csv')
osa_kent = pd.read_csv(r'C:\Users\OOC User\Documents\OOC\Data\Hustle\Groups\OSA\OSA Kent.csv')
osa_akron = pd.read_csv(r'C:\Users\OOC User\Documents\OOC\Data\Hustle\Groups\OSA\OSA University of Akron.csv')

# %%
df = pd.concat([osa_uc, osa_osu, osa_cs, osa_cles, osa_cle, osa_cwru, osa_kent, osa_akron])

# %%
# df

# %%
a = len(df['phone_number'])
print(f'{a} total phone numbers')
# Out:
# 614 total phone numbers

# %% [markdown]
# # Row Coverage

# %%
df.count().plot(kind='barh', figsize=(7, 8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Opt-outs

# %%
df['opted_out'].value_counts()
# Out:
# False    543
# True      71
# Name: opted_out, dtype: int64

# %%
a = df.loc[df['opted_out']==True,:]
b = pd.to_datetime(a['opted_out_at'])
b.dt.year.value_counts()
# Out:
# 2022    65
# 2019     2
# 2020     1
# 2016     1
# 2021     1
# 2018     1
# Name: opted_out_at, dtype: int64
