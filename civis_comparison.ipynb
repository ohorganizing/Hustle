# %% [markdown]
# # Comparing hustle direct exports to civis sync
# - are all records from hustle importing into civis?

# %%
import pandas as pd
import numpy as np

pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %%
civis_actions = pd.read_csv('civis_actions_02232022.csv', dtype='str')
civis_messages = pd.read_csv('civis_messages_02232022.csv', dtype='str')
civis_leads = pd.read_csv('civis_leads_02232022.csv', dtype='str')

# %%
hustle_actions = pd.read_csv(r'C:\Users\OOC User\Documents\OOC\Data\Hustle\actions_02232022.csv', dtype='str')
hustle_messages = pd.read_csv(r'C:\Users\OOC User\Documents\OOC\Data\Hustle\messages_02232022.csv', dtype='str')
hustle_leads = pd.read_csv(r'C:\Users\OOC User\Documents\OOC\Data\Hustle\leads_02232022.csv', dtype='str')

# %% [markdown]
# ## Actions
# - no 'id' field in hustle exports, compare dataset sizes instead?

# %%
civis_actions.sort_values(by='created_at').head(2)#.shape
# Out:
#               id           created_at           updated_at organization_id  \
# 5739  F3bG4E4O8R  2016-07-05 15:26:53  2016-07-05 15:26:53      6yhOdwbikO
# 5162  6kH0wbk9a3  2016-07-07 18:52:04  2016-07-07 18:52:04      6yhOdwbikO
#
#          lead_id    agent_id     goal_id goal_step_id            type  \
# 5739  6LvDPXArVx  jD7YvlCHte  z02e3vAsY8   KvrAxXc7Sg  rsvp_attending
# 5162  6mjiAcGtNh  jD7YvlCHte  z02e3vAsY8   KvrAxXc7Sg  rsvp_attending
#
#       value_str survey_question_id survey_response_id  account_id
# 5739  attending                NaN                NaN  IznJkm4h8y
# 5162  attending                NaN                NaN  IznJkm4h8y

# %%
hustle_actions.sort_values(by='action_created_at').head(2)#.shape
# Out:
#                 action_created_at action_value_type action_value  \
# 7903  2016-07-05 15:26:53.964 UTC              rsvp    attending
# 7902  2016-07-07 18:52:04.943 UTC              rsvp    attending
#
#      van_ohio_org_collab_xrwsac5jmz_survey_question_id  \
# 7903                                               NaN
# 7902                                               NaN
#
#      van_ohio_org_collab_xrwsac5jmz_survey_question_name  \
# 7903                                                NaN
# 7902                                                NaN
#
#      van_ohio_org_collab_xrwsac5jmz_survey_response_id  \
# 7903                                               NaN
# 7902                                               NaN
#
#      van_amos_tkn2kffo6e_survey_question_id  \
# 7903                                    NaN
# 7902                                    NaN
#
#      van_amos_tkn2kffo6e_survey_question_name  \
# 7903                                      NaN
# ...

# %% [markdown]
# #### more actions in civis than hustle?

# %% [markdown]
# # Messages

# %%
civis_messages.shape
# Out:
# (661095, 15)

# %%
hustle_messages.shape
# Out:
# (661460, 36)

# %% [markdown]
# #### less than 400 messages missing, not too worried about it

# %% [markdown]
# # Leads

# %%
civis_leads.shape
# Out:
# (515171, 19)

# %%
hustle_leads.shape
# Out:
# (564592, 37)

# %% [markdown]
# #### ~50k leads missing from civis
